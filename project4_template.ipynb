# %% [markdown]
# # [reduce the time that cars spend on the test bench]

# %% [markdown]
# *   기간 : 2023-06-15 ~ 2023-06-22
# *   리더 : 이건희
# *   정의 : Daimler 테스트를 통과하는데 걸리는 시간에 대한 예측
# *   목적 : 도로를 주행하기 전에 각각의 고유한 차량 구성의 안전성과 신뢰성을 보장하기 위한 테스트 시스템(Daimler)의 기준을 낮추지 않고 그 속도를 향상시켜 CO<sub>2</sub>
# 배출량을 줄이기 위해서 주어진 데이터 세트를 이용하여 테스트에 걸리는 시간을 예측하는 것을 r2_score를 통해 평가

# %% [markdown]
# ## [할 일 목록]

# %% [markdown]
# 1. EDA
#
# 2. model select
#
# 3. hyper parameter optimize

# %% [markdown]
# ## [이슈 항목]

# %% [markdown]
# pob 1) object type의 변수가 가지는 값이 train 과 test가 다른 값이 존재 (test data에는 존재하나 train data에는 없는 값이 존재)
# sol)
# &ensp;1. 데이터에 대한 label encoding
# &ensp;2. train과 test data를 합쳐 모든 값에 대한 one-hot-encoding
# &ensp;3. 그 데이터 drop
